# %%
import warnings
warnings.filterwarnings('ignore')

# !pip install -q seaborn
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from keras.applications.vgg19 import VGG19
from tensorflow.keras import layers
from keras.models import Model
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Flatten, Dense, Dropout, BatchNormalization
from keras.preprocessing import image
from keras.layers import Dense,GlobalAveragePooling2D
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from PIL import Image
BATCH_SIZE = 64
n_classes = 6

# VGG19 base model
conv_base = VGG19(
    include_top=False,
    weights='imagenet',
    input_shape=(224, 224, 3)
)

# Freeze all layers except the last two
for layer in conv_base.layers:
    layer.trainable = False

# Top model
top_model = conv_base.output
top_model = GlobalAveragePooling2D()(top_model)
top_model = Dense(1024,activation='relu')(top_model) 
top_model = Dense(1024,activation='relu')(top_model) 
top_model = Dense(512,activation='relu')(top_model) 
output_layer = Dense(n_classes, activation='softmax')(top_model)

# Final Model
model = Model(inputs=conv_base.input, outputs=output_layer)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
def plot_random_images(generator, num_images=20):
    # Get a batch of data from the generator
    images, labels = next(generator)

    # Get random indices for selecting images
    random_indices = np.random.choice(images.shape[0], num_images, replace=False)

    # Plot the selected images
    fig, axs = plt.subplots(4, 5, figsize=(15, 12))
    fig.suptitle('Random 20 Images from the Generator', fontsize=16)

    for i, ax in enumerate(axs.flatten()):
        index = random_indices[i]
        image = images[index]
        label = labels[index]

        # Display the image
        ax.imshow(image)
        ax.set_title(f'Class: {np.argmax(label)}')
        ax.axis('off')

    plt.show()

# %%
data_path = 'dataset_garbage'

# %%
original_data = ImageDataGenerator(rescale=1./255).flow_from_directory(data_path, target_size = (224, 224), batch_size = BATCH_SIZE, class_mode="categorical")
plot_random_images(original_data)
# Out:
# Found 4650 images belonging to 6 classes.

# %%
gen_train = ImageDataGenerator(preprocessing_function=preprocess_input) # VGG19 preprocessing
full_data = gen_train.flow_from_directory(data_path, target_size = (224, 224), batch_size = BATCH_SIZE, class_mode="categorical")
plot_random_images(full_data)
# Out:
# Found 4650 images belonging to 6 classes.

# %%
# Extract filenames and labels from the DirectoryIterator
filenames = full_data.filenames
labels = full_data.labels
class_mapping = {value: str(key) for key, value in full_data.class_indices.items()}
labels = [class_mapping[label] for label in labels]

filenames[:5], labels[:5]
# Out:
# (['battery/battery1.jpg',
#   'battery/battery10.jpg',
#   'battery/battery100.jpg',
#   'battery/battery101.jpg',
#   'battery/battery102.jpg'],
#  ['battery', 'battery', 'battery', 'battery', 'battery'])

# %%
# Split the data into training and testing sets
train_filenames, test_filenames, train_labels, test_labels = train_test_split(
    filenames, labels, test_size=0.1, random_state=42)

# Create DataFrames for training and testing
train_df = pd.DataFrame({'filename': train_filenames, 'class': train_labels})
test_df = pd.DataFrame({'filename': test_filenames, 'class': test_labels})

# Create separate generators for training and testing using flow_from_dataframe
train_data = gen_train.flow_from_dataframe(train_df, directory=data_path, target_size=(224, 224),
                                           batch_size=BATCH_SIZE, class_mode="categorical",
                                           shuffle=True, seed=42)

test_data = gen_train.flow_from_dataframe(test_df, directory=data_path, target_size=(224, 224),
                                          batch_size=BATCH_SIZE, class_mode="categorical",
                                          shuffle=False)
# Out:
# Found 4185 validated image filenames belonging to 6 classes.
# Found 465 validated image filenames belonging to 6 classes.

# %%
num_epochs = 200
opt = Adam(learning_rate=0.0001)
model.compile(
    optimizer=opt, 
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
checkpoint = ModelCheckpoint(
    filepath='model.vgg19.keras',
    save_best_only=True,
    save_weights_only=False,
    verbose=1
)
early = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv4 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv4 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv4 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │       525,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 6)              │         3,078 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,127,174 (84.41 MB)
#  Trainable params: 2,102,790 (8.02 MB)
#  Non-trainable params: 20,024,384 (76.39 MB)

# %%
n_steps = train_data.samples // BATCH_SIZE
n_val_steps = test_data.samples // BATCH_SIZE
n_steps, n_val_steps
# Out:
# (65, 7)

# %%
result = model.fit(
    train_data, 
    epochs=num_epochs, 
    steps_per_epoch=n_steps,
    validation_data=test_data, 
    validation_steps=n_val_steps,
    callbacks=[early, checkpoint, reduce_lr]
)
# Out:
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731835425.149127      74 service.cc:145] XLA service 0x7c64180111d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1731835425.149180      74 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1731835425.149186      74 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1731835450.716768      74 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 710ms/step - accuracy: 0.6260 - loss: 1.0820
# Epoch 1: val_loss improved from inf to 0.32025, saving model to model.vgg19.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 83s 806ms/step - accuracy: 0.6284 - loss: 1.0747 - val_accuracy: 0.9129 - val_loss: 0.3202 - learning_rate: 1.0000e-04
# Epoch 2/200
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 22s 345ms/step - accuracy: 0.8438 - loss: 0.4519
# Epoch 2: val_loss improved from 0.32025 to 0.13980, saving model to model.vgg19.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 14s 207ms/step - accuracy: 0.8438 - loss: 0.4519 - val_accuracy: 0.9412 - val_loss: 0.1398 - learning_rate: 1.0000e-04
# Epoch 3/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.9431 - loss: 0.1778
# Epoch 3: val_loss did not improve from 0.13980
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 27s 387ms/step - accuracy: 0.9432 - loss: 0.1778 - val_accuracy: 0.9040 - val_loss: 0.2839 - learning_rate: 1.0000e-04
# Epoch 4/200
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 21s 330ms/step - accuracy: 0.9062 - loss: 0.2177
# Epoch 4: val_loss did not improve from 0.13980
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9062 - loss: 0.2177 - val_accuracy: 0.8824 - val_loss: 0.1924 - learning_rate: 1.0000e-04
# Epoch 5/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.9671 - loss: 0.1173
# Epoch 5: val_loss did not improve from 0.13980
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 27s 381ms/step - accuracy: 0.9672 - loss: 0.1171 - val_accuracy: 0.9308 - val_loss: 0.2633 - learning_rate: 1.0000e-04
# Epoch 6/200
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 21s 336ms/step - accuracy: 0.9844 - loss: 0.0589
# Epoch 6: val_loss improved from 0.13980 to 0.11606, saving model to model.vgg19.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9844 - loss: 0.0589 - val_accuracy: 0.9412 - val_loss: 0.1161 - learning_rate: 1.0000e-04
# Epoch 7/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.9860 - loss: 0.0647
# Epoch 7: val_loss did not improve from 0.11606
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 28s 395ms/step - accuracy: 0.9860 - loss: 0.0647 - val_accuracy: 0.9442 - val_loss: 0.2279 - learning_rate: 1.0000e-04
# Epoch 8/200
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 21s 340ms/step - accuracy: 0.9844 - loss: 0.0533
# Epoch 8: val_loss improved from 0.11606 to 0.08236, saving model to model.vgg19.keras
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9844 - loss: 0.0533 - val_accuracy: 1.0000 - val_loss: 0.0824 - learning_rate: 1.0000e-04
# Epoch 9/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.9951 - loss: 0.0407
# Epoch 9: val_loss did not improve from 0.08236
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 27s 391ms/step - accuracy: 0.9951 - loss: 0.0406 - val_accuracy: 0.9397 - val_loss: 0.2420 - learning_rate: 1.0000e-04
# Epoch 10/200
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 21s 334ms/step - accuracy: 1.0000 - loss: 0.0249
# Epoch 10: val_loss did not improve from 0.08236
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0249 - val_accuracy: 0.9412 - val_loss: 0.1031 - learning_rate: 1.0000e-04
# Epoch 11/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.9983 - loss: 0.0248
# Epoch 11: val_loss did not improve from 0.08236
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 27s 388ms/step - accuracy: 0.9983 - loss: 0.0248 - val_accuracy: 0.9397 - val_loss: 0.2414 - learning_rate: 1.0000e-04
# Epoch 12/200
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 21s 336ms/step - accuracy: 1.0000 - loss: 0.0302
# Epoch 12: val_loss did not improve from 0.08236
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0302 - val_accuracy: 0.9412 - val_loss: 0.1042 - learning_rate: 1.0000e-04
# Epoch 13/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.9998 - loss: 0.0157
# Epoch 13: val_loss did not improve from 0.08236
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 27s 392ms/step - accuracy: 0.9998 - loss: 0.0157 - val_accuracy: 0.9420 - val_loss: 0.2378 - learning_rate: 1.0000e-04
# Epoch 14/200
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 21s 341ms/step - accuracy: 0.9844 - loss: 0.0288
# Epoch 14: val_loss did not improve from 0.08236
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9844 - loss: 0.0288 - val_accuracy: 0.9412 - val_loss: 0.0824 - learning_rate: 2.0000e-05
# Epoch 15/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.9986 - loss: 0.0129
# Epoch 15: val_loss did not improve from 0.08236
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 27s 391ms/step - accuracy: 0.9986 - loss: 0.0129 - val_accuracy: 0.9375 - val_loss: 0.2382 - learning_rate: 2.0000e-05
# Epoch 16/200
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 21s 339ms/step - accuracy: 0.9844 - loss: 0.0422
# Epoch 16: val_loss did not improve from 0.08236
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9844 - loss: 0.0422 - val_accuracy: 0.9412 - val_loss: 0.1041 - learning_rate: 2.0000e-05
# Epoch 17/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.9984 - loss: 0.0108
# Epoch 17: val_loss did not improve from 0.08236
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 27s 388ms/step - accuracy: 0.9984 - loss: 0.0108 - val_accuracy: 0.9420 - val_loss: 0.2377 - learning_rate: 2.0000e-05
# Epoch 18/200
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 21s 339ms/step - accuracy: 1.0000 - loss: 0.0071
# Epoch 18: val_loss did not improve from 0.08236
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 0.9412 - val_loss: 0.1044 - learning_rate: 2.0000e-05
# Epoch 19/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9990 - loss: 0.0107
# Epoch 19: val_loss did not improve from 0.08236
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 27s 390ms/step - accuracy: 0.9990 - loss: 0.0107 - val_accuracy: 0.9420 - val_loss: 0.2404 - learning_rate: 4.0000e-06
# Epoch 20/200
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 21s 338ms/step - accuracy: 1.0000 - loss: 0.0105
# Epoch 20: val_loss did not improve from 0.08236
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0105 - val_accuracy: 0.9412 - val_loss: 0.1113 - learning_rate: 4.0000e-06
# Epoch 21/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.9990 - loss: 0.0101
# Epoch 21: val_loss did not improve from 0.08236
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 27s 393ms/step - accuracy: 0.9990 - loss: 0.0101 - val_accuracy: 0.9420 - val_loss: 0.2416 - learning_rate: 4.0000e-06
# Epoch 22/200
#  1/65 ━━━━━━━━━━━━━━━━━━━━ 21s 339ms/step - accuracy: 1.0000 - loss: 0.0145
# Epoch 22: val_loss did not improve from 0.08236
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0145 - val_accuracy: 0.9412 - val_loss: 0.1160 - learning_rate: 4.0000e-06
# Epoch 23/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.9993 - loss: 0.0097
# Epoch 23: val_loss did not improve from 0.08236
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 27s 389ms/step - accuracy: 0.9993 - loss: 0.0097 - val_accuracy: 0.9397 - val_loss: 0.2414 - learning_rate: 4.0000e-06

# %%
plt.title("Accuracy")
plt.plot(result.history["accuracy"])
plt.plot(result.history["val_accuracy"])
plt.show()

# %%
plt.title("Loss")
plt.plot(result.history["loss"])
plt.plot(result.history["val_loss"])
plt.show()

# %%
plt.plot(result.history['accuracy'])
plt.plot(result.history['val_accuracy'])
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title("model accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Accuracy","Validation Accuracy","loss","Validation Loss"])
plt.show()

# %%
model.save("model_vgg19.keras")

# %%
predictions = model.predict(test_data)

# Get the predicted class labels
predicted_labels = np.argmax(predictions, axis=1)

# Get the true class labels
true_labels = test_data.classes

# Compute confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Plot confusion matrix using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=test_data.class_indices.keys(),
            yticklabels=test_data.class_indices.keys())
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Print classification report
class_names = list(test_data.class_indices.keys())
print(classification_report(true_labels, predicted_labels, target_names=class_names))
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 371ms/step
#               precision    recall  f1-score   support
#
#      battery       0.98      0.98      0.98        87
#        glass       0.92      0.92      0.92        73
#        metal       0.90      0.93      0.91        69
#      organic       0.97      0.98      0.98        64
#        paper       0.97      0.98      0.97        92
#      plastic       0.93      0.89      0.91        80
#
#     accuracy                           0.95       465
#    macro avg       0.94      0.95      0.94       465
# weighted avg       0.95      0.95      0.95       465

# %%
output_class = ["battery", "glass", "metal","organic", "paper", "plastic"]

def preprocessing_input(img_path):
    img = image.load_img(img_path, target_size=(224, 224))
    img = image.img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = preprocess_input(img) # VGG16 preprocess_input
    return img

def plot_images(original, preprocessed):
    fig, axs = plt.subplots(1, 2, figsize=(10, 5))

    axs[0].imshow(original)
    axs[0].set_title('Original Image')
    axs[0].axis('off')

    # Remove the batch dimension for display
    preprocessed = np.squeeze(preprocessed, axis=0)

    axs[1].imshow(preprocessed)
    axs[1].set_title('Preprocessed Image')
    axs[1].axis('off')

    plt.show()

def predict_user(img_path):
    img = preprocessing_input(img_path)
    plot_images(Image.open(img_path), img)
    predicted_array = model.predict(img)
    predicted_value = output_class[np.argmax(predicted_array)]
    predicted_accuracy = round(np.max(predicted_array) * 100, 2)
    print("Your waste material is", predicted_value, "with", predicted_accuracy, "% accuracy.")

# %%
predict_user('/kaggle/input/test-data/plastic100.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Your waste material is plastic with 93.58 % accuracy.
